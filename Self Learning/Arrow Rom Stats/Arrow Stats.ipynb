# %%
# Loading required libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # The latest stats are grabbed everytime the code executes

# %%
# loading tables 
tables = pd.read_html("https://stats.arrowos.net/")

print(tables[1])
# Out:
#                   Codename  Pie Installs  Oreo Installs  Total  Unnamed: 4
# 0                  z2_plus         10224           1758  11982         NaN
# 1                   whyred          9686            314  10000         NaN
# 2                  santoni          5570           3592   9162         NaN
# 3                   potter          8863            256   9119         NaN
# 4                     mido          7923            251   8174         NaN
# 5                   athene          7095              0   7095         NaN
# 6                    kenzo          5749            523   6272         NaN
# 7                   tissot          5049              0   5049         NaN
# 8                    bacon          4618              0   4618         NaN
# 9                   treble          3899            545   4444         NaN
# 10                   markw          3866              0   3866         NaN
# 11                      s2          3155            333   3488         NaN
# 12                   vince          3097            192   3289         NaN
# 13                  oxygen          2660             37   2697         NaN
# 14                 sanders          2100            285   2385         NaN
# 15                oneplus3          2119            228   2347         NaN
# 16                    land          1758            140   1898         NaN
# 17                  gemini          1622              0   1622         NaN
# 18                zenfone3          1053            115   1168         NaN
# 19                    kiwi           636            495   1131         NaN
# 20                   X00TD           773             94    867         NaN
# 21                oneplus2           831              0    831         NaN
# 22               beryllium           762             37    799         NaN
# 23                 polaris           711              0    711         NaN
# 24                   rolex           490            132    622         NaN
# 25                dumpling           485              0    485         NaN
# 26                   sagit           408              9    417         NaN
# 27            cheeseburger           392              0    392         NaN
# 28                   jason           343              3    346         NaN
# 29                      x2           300              0    300         NaN
# ..                     ...           ...            ...    ...         ...
# 63                    X00T            13              0     13         NaN
# 64                    mata            12              0     12         NaN
# 65                   z3tcw             0             11     11         NaN
# 66                    klte            10              0     10         NaN
# 67                 tiffany            10              0     10         NaN
# 68                    riva             8              0      8         NaN
# 69                      m8             5              2      7         NaN
# 70            serranovelte             5              1      6         NaN
# 71                    chef             5              0      5         NaN
# 72                    Z00T             5              0      5         NaN
# 73                  honami             0              5      5         NaN
# 74                  harpia             4              0      4         NaN
# 75                    Z00L             4              0      4         NaN
# 76                     NaN             3              0      3         NaN
# 77                  G36C1H             1              1      2         NaN
# 78                  osprey             1              1      2         NaN
# 79              v2.0_markw             1              0      1         NaN
# 80       santoni_userdebug             1              0      1         NaN
# 81                     pme             1              0      1         NaN
# 82                oneplus6             1              0      1         NaN
# 83                shamrock             1              0      1         NaN
# 84                       x             1              0      1         NaN
# 85               crackling             0              1      1         NaN
# 86                  clover             1              0      1         NaN
# 87                JTAHolic             1              0      1         NaN
# 88  santoni_port_from_mido             1              0      1         NaN
# 89                 herolte             0              1      1         NaN
# 90                 rendang             1              0      1         NaN
# 91                    h811             0              1      1         NaN
# 92                     GSI           566             93    659         NaN
#
# [93 rows x 5 columns]

# %% [markdown]
# # the stats are saved to a csv file on the local directory

# %%
# saving this table to a csv file
tables[1].to_csv("stats by device.csv", index=False)

# %%
# loading the data back into dataframe
stats_device = pd.read_csv("stats by device.csv")

# %%
# dropping the NaN column
stats_device = stats_device.drop('Unnamed: 4' ,axis = 1)
stats_device_top10 = stats_device[0:10]

# %% [markdown]
# # Top 10 devices by install base in Pie

# %%
# Pie chart for pie installs
plt.figure(figsize = (10 ,10))
labels = stats_device_top10['Codename']
sizes = stats_device_top10['Pie Installs']
#colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
# bar charts for pie installs
plt.figure(figsize = (10 ,10))
height = stats_device_top10['Pie Installs']
bars = stats_device_top10['Codename']
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Rotation of the bars names
plt.xticks(y_pos, bars, rotation=90)
 
# Custom the subplot layout
plt.subplots_adjust(bottom=0.4, top=0.99)

 
# Show graphic
plt.show()

# %% [markdown]
# # Top 10 devices by install base in Oreo

# %%
# pie chart for oreo installs
plt.figure(figsize = (10 ,10))
labels = stats_device_top10['Codename']
sizes = stats_device_top10['Oreo Installs']
#colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
# Bar charts for oreo installs
plt.figure(figsize = (10 ,10))
height = stats_device_top10['Oreo Installs']
bars = stats_device_top10['Codename']
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Rotation of the bars names
plt.xticks(y_pos, bars, rotation=90)
 
# Custom the subplot layout
plt.subplots_adjust(bottom=0.4, top=0.99)
 
# Show graphic
plt.show()
